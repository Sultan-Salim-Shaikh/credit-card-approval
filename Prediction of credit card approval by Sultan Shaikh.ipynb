# %% [markdown]
# ## **Project proposal to predict credit card approval** [ EDA & ML ]

# %% [markdown]
# A project proposal to predict credit card approval involves using data analysis and machine learning techniques to develop a predictive model that can determine the likelihood of an individual's credit card application being approved or denied.
#
# The project would typically involve collecting data on credit card applications and their corresponding outcomes, including variables such as income, employment status, credit score, and other relevant factors. This data would then be used to train a machine learning algorithm to identify patterns and correlations between these variables and the likelihood of approval.
#
# The **proposed project** would have several key steps, including data collection and cleaning, exploratory data analysis, feature engineering, model selection and training, and model evaluation and testing. In addition, it would be important to consider ethical considerations and potential biases in the data and model outputs.
#
# The **end goal** of the project would be to develop a reliable and accurate model that could be used by credit card companies to assess creditworthiness and make informed decisions about whether to approve or deny an applicant's credit card application.

# %% [markdown]
# ## Section 1

# %% [markdown]
# #### 1. Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?
# * Forecasting the suitability of a client for credit card approval is pivotal for banks in the contemporary landscape, as it enables them to mitigate risks and enhance profitability. Given the surge in credit card applications and the escalating concern regarding credit card fraud, it is imperative for banks to adeptly evaluate the creditworthiness of applicants.
#
# * Harnessing the power of data analytics and machine learning algorithms, banks can scrutinize extensive datasets to discern patterns indicative of a favorable client. Parameters such as income, employment status, credit history, and spending behavior are considered in this analysis. By identifying these patterns, banks can make well-informed decisions on whether to approve an application and determine an appropriate interest rate.
#
# * This systematic approach aids banks in curbing the risk of default and credit card fraud, averting potential financial setbacks and safeguarding their reputation. Furthermore, it enables banks to streamline their marketing strategies by pinpointing customers likely to use credit responsibly, thereby maximizing revenue generation.
#
# * In summary, accurately predicting a client's suitability is indispensable for banks in the contemporary landscape. This practice not only ensures profitability and risk mitigation but also enables banks to deliver optimal services to their customers.

# %% [markdown]
# ### 2. How is it going to impact the banking sector?
# * In the contemporary financial landscape, the imperative to forecast and endorse creditworthy clients is paramount for banks. The upswing in credit card applications, accompanied by escalating concerns about credit card fraud, underscores the need for precise evaluation of applicants' creditworthiness to mitigate risks and bolster overall profitability.
#
# * The utilization of data analytics and machine learning algorithms holds pivotal significance for banks, enabling them to meticulously examine extensive datasets and unveil patterns indicative of a trustworthy client. Crucial factors such as income, employment status, credit history, and spending behavior contribute to shaping these discernible patterns. Through this analytical approach, banks can make well-informed decisions regarding application approval and the determination of appropriate interest rates.
#
# * This predictive process functions as a robust risk mitigation strategy for banks, safeguarding them against potential defaults and credit card fraud—both of which can entail substantial financial and reputational consequences. Furthermore, it empowers banks to strategically tailor their marketing endeavors, targeting individuals most likely to use credit responsibly and contribute to the bank's revenue stream.
#
# * In essence, the ability to predict creditworthy clients emerges as indispensable for banks in today's dynamic environment. This capability ensures sustained profitability, risk reduction, and the delivery of optimal services to their clientele.

# %% [markdown]
# ### 3.If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.

# %% [markdown]
# * Machine Learning proves invaluable in scrutinizing extensive datasets to discern patterns and factors influencing both credit card approval and disapproval. This analysis encompasses critical information such as credit scores, income levels, employment history, and other financial data. Through Data Visualization, correlations between various factors and the likelihood of credit card approval can be identified, empowering banks to make more precise decisions.
#
# * Utilizing ML, predictive models can be developed to forecast the probability of credit card approval for individual applicants based on their profile data. These models are trained on historical data to identify pertinent patterns and factors affecting credit card approval, enabling accurate predictions for new applicants.
#
# * Moreover, ML can play a pivotal role in the continuous monitoring of credit card applications and approvals, identifying patterns or trends indicative of fraudulent activity or other types of risks. This proactive approach allows banks to pinpoint potential fraudsters and implement measures to prevent fraud, thereby safeguarding their customers.
#
# * In summary, ML-based methods significantly enhance credit card approval prediction for banks in India by delivering more accurate and reliable data analysis, predictive modeling, and advanced fraud detection capabilities.

# %% [markdown]
# #### I have Resolved the Data in 2 Parts:
#
# * 1 . SQL
# * 2 . Machine Learning
#      -  Machine Learning is divided into Two Parts
#           - 3 Data Visualization
#           - 4 Machine Learning Models

# %% [markdown]
# # TABLE OF CONTENTS
# ## 1. SQL
# * 1.1 Exploratory Data Analysis (EDA)
# * 1.2 Column Renaming
# * 1.3 Index Sorting
# * 1.4 Handling Missing Values
#     * 1.4.1 Visualizing Missing Values
# * 1.5 Removing Duplicates
# * 1.6 Dropping Null Values
# * 1.7 Filling Null Values
# * 1.8 Converting Negative [Days] to Years
# * 1.9 Employment_Length Imputation
#     * 1.9.1 Data Encoding for Employment_Length Imputation
#     * 1.9.2 Imputation Methods [Mean, Median, Mode, KNN, MICE]
# * 1.10 Column Renaming and Rearranging

# %% [markdown]
# # TABLE OF CONTENTS
# ## 2. Machine Learning
# * 2.1 Exploratory Data Analysis (EDA)
# * 2.2 Column Renaming
# * 2.3 Dropping Null Values
# * 2.4 Converting Negative [Days] to Years
# * 2.5 Development of Visualization and Value Count Functions
#
# ## 3. Data Visualization
# * 3.1 Gender [Univariate]
# * 3.2 Age [Univariate, Bivariate]
# * 3.3 Marital_Status [Univariate, Bivariate]
# * 3.4 Family_Members [Univariate]
# * 3.5 Children_Count [Univariate, Bivariate]
# * 3.6 Dwelling [Univariate]
# * 3.7 Income [Univariate, Bivariate]
# * 3.8 Type_Income [Univariate]
# * 3.9 Education_Level [Univariate]
# * 3.10 Employed_Years [Univariate, Bivariate]
# * 3.11 Has_A_Car [Univariate]
# * 3.12 Has_A_Property [Univariate]
# * 3.13 Has_A_Work_Phone [Univariate]
# * 3.14 Has_A_Mobile_Phone [Univariate]
# * 3.15 Has_A_Phone [Univariate]
# * 3.16 Has_An_Email [Univariate]
# * 3.17 Outcome (Target Variable)
# * 3.18 Numerical vs. Numerical Features (Correlation & Scatter Plot)
# * 3.19 Family Member Count vs. Children Count (Numerical vs. Numerical Feature Comparison)
# * 3.20 Correlation Analysis
# * 3.21 Chi-Square Test
#
# ## 4. Machine Learning
# * 4.1 Feature Removal Based on Visualization
# * 4.2 Data Encoding of Nominal Data [get_dummies]
# * 4.3 Data Encoding of Ordinal Data [Label Encoder]
# * 4.4 Data Imputation [Mean, Median, Mode, KNN, MICE]
# * 4.5 Outlier Removal
# * 4.6 Construction of Machine Learning Models

# %% [markdown]
# # Importing the Necessary Packages

# %%
# For Data Analysis and Mathamatical Function usingd the below Lib:-
import numpy as np 
import pandas as pd

#Data Visualization of Missing value using the below lib:-
import missingno as mn

#Data Visualization Libraries
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

#Remving the Warning 
import warnings
warnings.filterwarnings('ignore')

#Imputating the Missing value using the Below Libraries
from fancyimpute import KNN , IterativeImputer
from sklearn.impute import SimpleImputer

#for spliting the data using the below lib
from sklearn.model_selection import cross_val_score

#for Data Encoding
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

#for Normalizing and standardization of the data
from sklearn.preprocessing import MinMaxScaler,StandardScaler

#Machine Learning models Libraries: 
from sklearn.ensemble import AdaBoostClassifier,BaggingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold,cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
# Importing the dataset to the Enviroment using the Pandas Library
credit_raw = pd.read_csv("Credit_card.csv")
df_credit  = pd.read_csv("Credit_card_label.csv")

credit_raw = credit_raw.merge(df_credit,how = "inner", on=["Ind_ID"])
#Merging the file on the basis of the IND_ID

credit_SQL = credit_raw.copy() # Making a copy for SQl part of the project.
credit_ML  = credit_raw.copy() # Making a copy for Ml  part of the project.

# %% [markdown]
# # **SQL PART OF THE PROJECT**

# %% [markdown]
# * We will Do the folowing steps for SQL part of the Project
#     - Rename the Columns
#     - Remove the NaN Values from the data
#     - Birthday_Count and Employed_days feature in the Dataset has to be converted to the years Instead of days .
#     - Type_Occupation Featues in the dataset contains the NaN values which we can replace as "Not_Employed".
#     - Hence the dataset is ready for the SQL

# %% [markdown]
# ## 1.1 Exploratory Data Analysis (EDA)

# %%
credit_SQL.head() #To see any Unusual activity in the dataset
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0      180000.00
# 1  5009744      F         Y             N         0      315000.00
# 2  5009746      F         Y             N         0      315000.00
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0      315000.00
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
credit_SQL.tail()
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0      225000.00
# 1545  5115992      M         Y             Y         2      180000.00
# 1546  5118219      M         Y             N         0      270000.00
# 1547  5053790      F         Y             Y         0      225000.00
#
#                Type_Income                      EDUCATION  \
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 1543               Married  House / apartment       -11957.00          -2182
# ...

# %%
credit_SQL.describe(include='all')
# Out:
#            Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# count     1548.00   1541      1548          1548   1548.00        1525.00
# unique        NaN      2         2             2       NaN            NaN
# top           NaN      F         N             Y       NaN            NaN
# freq          NaN    973       924          1010       NaN            NaN
# mean   5078920.35    NaN       NaN           NaN      0.41      191399.33
# std      41717.59    NaN       NaN           NaN      0.78      113253.00
# min    5008827.00    NaN       NaN           NaN      0.00       33750.00
# 25%    5045069.75    NaN       NaN           NaN      0.00      121500.00
# 50%    5078841.50    NaN       NaN           NaN      0.00      166500.00
# 75%    5115673.00    NaN       NaN           NaN      1.00      225000.00
# max    5150412.00    NaN       NaN           NaN     14.00     1575000.00
#
#        Type_Income                      EDUCATION Marital_status  \
# ...

# %% [markdown]
# ## 1.1 Column Renaming:

# %%
credit_SQL.columns # using the df.columns function to ensure is their any spaces in between or any defects
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'label'],
#       dtype='object')

# %%
# rename the features to a more readable feature names
credit_SQL= credit_SQL.rename(columns={
    "Ind_ID"            :"ID",
    'GENDER'            :'Gender',
    'Car_Owner'         :'Has_a_car',
    'Propert_Owner'     :'Has_a_property',
    'CHILDREN'          :'Children_count',
    'Annual_income'     :'Income',
    'NAME_INCOME_TYPE'  :'Employment_status',
    'EDUCATION'         :'Education_level',
    'Housing_type'      :'Dwelling',
    'Employed_days'     :'Employment_length',
    'Mobile_phone'      :'Has_a_mobile_phone',
    'Work_Phone'        :"Has_a_work_phone",
    'Phone'             :'Has_a_phone',
    'EMAIL_ID'          :'Has_an_email',
    'Type_Occupation'   :'Job_Title',
    'Fmaily_Member'     :'Family_member_count',
    })

# %% [markdown]
# ## 1.2 Index Sorting:

# %%
## Sorting the values in the Ascending order on the Basis of 
credit_SQL = credit_SQL.sort_values("ID")
credit_SQL = credit_SQL.reset_index()
credit_SQL.drop("index",axis=1,inplace=True)
credit_SQL
# Out:
#            ID Gender Has_a_car Has_a_property  Children_count    Income  \
# 0     5008827      M         Y              Y               0 180000.00
# 1     5008865      F         Y              Y               2 135000.00
# 2     5008889      F         N              Y               0 247500.00
# 3     5009000      M         Y              Y               0 157500.00
# 4     5009023      F         N              Y               2 216000.00
# ...       ...    ...       ...            ...             ...       ...
# 1543  5150038      M         N              N               0 180000.00
# 1544  5150047      F         N              Y               0 283500.00
# 1545  5150164      F         N              N               0 135000.00
# 1546  5150221      M         Y              Y               0 116100.00
# 1547  5150412      F         N              Y               0  67500.00
#
#                Type_Income                Education_level  \
# ...

# %% [markdown]
# ## Insights:
# * We have 1548 Records a 19 features.
# * We can see their NaN values in the Job_titles.

# %% [markdown]
# ## 1.4 Handling the Missing Values

# %%
credit_SQL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1548 non-null   int64
#  1   Gender              1541 non-null   object
#  2   Has_a_car           1548 non-null   object
#  3   Has_a_property      1548 non-null   object
#  4   Children_count      1548 non-null   int64
#  5   Income              1525 non-null   float64
#  6   Type_Income         1548 non-null   object
#  7   Education_level     1548 non-null   object
#  8   Marital_status      1548 non-null   object
#  9   Dwelling            1548 non-null   object
#  10  Birthday_count      1526 non-null   float64
#  11  Employment_length   1548 non-null   int64
#  12  Has_a_mobile_phone  1548 non-null   int64
#  13  Has_a_work_phone    1548 non-null   int64
#  14  Has_a_phone         1548 non-null   int64
# ...

# %% [markdown]
# ## Insights:
# * We have Missing values in Gender , Income , Age , Job_Title columns

# %% [markdown]
# ## 1.4.1 Visualizing the Missing Values

# %%
#Lets have the missing values Visualization using the Missingno module
mn.matrix(credit_SQL)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Insights:
# * Gender , Income , Age and Job Title has the Missing Values
# * We have the Clear Look from the Visualization that There is No Relationship Between the Missing Values

# %%
mn.bar(credit_SQL)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Insight:
# * We will be able to see the frequency count of any feature using this function

# %% [markdown]
# ## 1.5 Removing Duplicates:

# %%
#lets drop the duplicated value from the data if any exist
print(credit_SQL.shape)
credit_SQL = credit_SQL.drop_duplicates()
print(credit_SQL.shape)
# Out:
# (1548, 19)
# (1548, 19)

# %% [markdown]
# #### Insights:
# * There are NO duplicates in the Dataset

# %%
#percentage of Null values
credit_SQL.isnull().sum()/1548 *100
# Out:
# ID                    0.00
# Gender                0.45
# Has_a_car             0.00
# Has_a_property        0.00
# Children_count        0.00
# Income                1.49
# Type_Income           0.00
# Education_level       0.00
# Marital_status        0.00
# Dwelling              0.00
# Birthday_count        1.42
# Employment_length     0.00
# Has_a_mobile_phone    0.00
# Has_a_work_phone      0.00
# Has_a_phone           0.00
# Has_an_email          0.00
# Job_Title            31.52
# Family_Members        0.00
# label                 0.00
# dtype: float64

# %% [markdown]
# #### Insights:
# * There are few columns where NaN values are 1% and <1% which van be dropped off using the dropna() function
# * And Job_Title values NaN values we are replacing it with Not_Employed

# %%
#checking the Null values of Columns and will handle it as the conclusion comes
print(credit_SQL.isnull().sum())
print("=====================================")
print(credit_SQL.dropna(subset=["Gender","Income","Birthday_count"],inplace=True))
print((credit_SQL.isnull().sum() / 1496 )*100) #percentage of Null values in each Columns
print("======================================")
# Out:
# ID                      0
# Gender                  7
# Has_a_car               0
# Has_a_property          0
# Children_count          0
# Income                 23
# Type_Income             0
# Education_level         0
# Marital_status          0
# Dwelling                0
# Birthday_count         22
# Employment_length       0
# Has_a_mobile_phone      0
# Has_a_work_phone        0
# Has_a_phone             0
# Has_an_email            0
# Job_Title             488
# Family_Members          0
# label                   0
# dtype: int64
# ...
# None
# ID                    0.00
# Gender                0.00
# Has_a_car             0.00
# Has_a_property        0.00
# Children_count        0.00
# Income                0.00
# Type_Income           0.00
# Education_level       0.00
# Marital_status        0.00
# Dwelling              0.00
# Birthday_count        0.00
# Employment_length     0.00
# Has_a_mobile_phone    0.00
# Has_a_work_phone      0.00
# Has_a_phone           0.00
# ...

# %% [markdown]
# ## 1.7 Filling Null Values

# %%
credit_SQL.Job_Title.replace(np.nan,"Not_Employed" , inplace = True)
print(credit_SQL.Job_Title.value_counts())
print("==============================")
print(print((credit_SQL.isnull().sum() / 1496 )*100))
# Out:
# Not_Employed             471
# Laborers                 259
# Core staff               171
# Managers                 130
# Sales staff              118
# Drivers                   85
# High skill tech staff     62
# Medicine staff            49
# Accountants               42
# Security staff            24
# Cleaning staff            20
# Cooking staff             19
# Private service staff     16
# Low-skill Laborers         9
# Secretaries                9
# Waiters/barmen staff       5
# HR staff                   3
# IT staff                   2
# Realty agents              2
# Name: Job_Title, dtype: int64
# ...
# ID                   0.00
# Gender               0.00
# Has_a_car            0.00
# Has_a_property       0.00
# Children_count       0.00
# Income               0.00
# Type_Income          0.00
# Education_level      0.00
# Marital_status       0.00
# Dwelling             0.00
# Birthday_count       0.00
# Employment_length    0.00
# Has_a_mobile_phone   0.00
# ...

# %% [markdown]
# ### Insights:
# All the Missing values in the data has been handleed Carefully.

# %% [markdown]
# ## 1.8 Converting Birthday_Count , Employment_Length from -(days) to Years

# %%
#bithday count is in the negative and day format which has to be converted
# Years 
age = np.abs((credit_SQL.Birthday_count)/365)
df_age = pd.DataFrame(age,dtype=int)
df_age = df_age.rename(columns={"Birthday_count":"Age"})
credit_SQL = pd.concat([credit_SQL,df_age],axis=1).drop("Birthday_count",axis=1)

days = np.abs((credit_SQL.Employment_length)/365)
df_days = pd.DataFrame(days,dtype=int)
df_days = df_days.rename(columns={"Employment_length":"Employed_Years"})
credit_SQL = pd.concat([credit_SQL,df_days],axis=1).drop("Employment_length",axis=1)

# %% [markdown]
# #### Insights:
# * We have converted all Birthday count to Age.
# * We have converted all the Employment_Length to Employed_Years.

# %% [markdown]
# ## 1.9  Employment_Length Imputation Employment_Length

# %% [markdown]
# ## Important
# **We will do the Imputation of the Employed_Years after doing the Data_Encoding**
# * To Get the Best Imputed Value and to Run all the Imputation KNN and MICE
# all the data should be Encoded

# %%
credit_df = credit_SQL.copy()

# %% [markdown]
# ## 1.9.1 Data Encoding for Employment_Length Imputation

# %%
# Gender , Car , Property  ---> Numerical Data
credit_df['Gender'].replace('M',0,inplace=True)
credit_df['Gender'].replace('F',1,inplace=True)
credit_df['Has_a_car'].replace('Y',0,inplace=True)
credit_df['Has_a_car'].replace('N',1,inplace=True)
credit_df['Has_a_property'].replace('Y',0,inplace=True)
credit_df['Has_a_property'].replace('N',1,inplace=True)


# Credit_Income ---> [ Categorical --> Numerical ]
LE1 = LabelEncoder()
credit_income = credit_df.copy()
ary1 = LE1.fit_transform(credit_income[["Type_Income"]])
df_Income = pd.DataFrame(ary1,columns=["Income_Type"])
credit_income = pd.concat([credit_income,df_Income],axis = 1 )
credit_income.drop("Type_Income",axis=1,inplace=True)
print("====================================================================")
print("====>",LE1.classes_,"<====") 
print("                  0","                1","         2","             3")
# Commericial assosciaye as 0 , Pensioner as 1 and so on
print("====================================================================")
credit_income.dropna() # we are able to see that there are some
#NaN values we are dealing it after LabelEncoding
print(credit_income.isnull().sum())
credit_income = credit_income.dropna()
credit_income

# JOB_Title ---> [ Categorical --> Numerical ]
LE2 = LabelEncoder()
credit_job = credit_income.copy()
ary2 = LE2.fit_transform(credit_job[["Job_Title"]])
df_job = pd.DataFrame(ary2,columns=["Job_Type"])
credit_job = pd.concat([credit_job,df_job],axis = 1 )
credit_job.drop("Job_Title",axis=1,inplace=True)
print(credit_job.shape)
print("==============================================================================")
print(credit_job.isnull().sum())
credit_job = credit_job.dropna()
print("==============================================================================")
credit_job 

# Education_Level ---> [ Categorical --> Numerical ]
LE3 = LabelEncoder()
credit_edu = credit_job.copy()
ary3 = LE3.fit_transform(credit_edu[["Education_level"]])
df_edu = pd.DataFrame(ary3,columns=["Education"])
credit_edu = pd.concat([credit_edu,df_edu],axis = 1 )
credit_edu.drop("Education_level",axis=1,inplace=True)
print(LE3.classes_)
print("==============================================================================")
print(credit_edu.isnull().sum())
credit_edu = credit_edu.dropna()
print("==============================================================================")
credit_edu
LE3 = LabelEncoder()
credit_edu = credit_job.copy()
ary3 = LE3.fit_transform(credit_edu[["Education_level"]])
df_edu = pd.DataFrame(ary3,columns=["Education"])
credit_edu = pd.concat([credit_edu,df_edu],axis = 1 )
credit_edu.drop("Education_level",axis=1,inplace=True)
print(LE3.classes_)
print("==============================================================================")
print(credit_edu.isnull().sum())
credit_edu = credit_edu.dropna()
print("==============================================================================")
credit_edu


# Marital ---> [ Categorical --> Numerical ]

credit_edu['Marital_status'].replace('Civil marriage',"Married",inplace=True)
credit_edu['Marital_status'].replace('Widow',"Separated",inplace=True)
credit_edu['Marital_status'].replace("Single / not married","Single",inplace=True)
print(credit_edu.Marital_status.value_counts())

from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
credit_marital = credit_edu.copy()
ary4 = ohe.fit_transform(credit_marital[["Marital_status"]]).toarray()
print(ohe.categories_)

df_Marital = pd.DataFrame(ary4,columns=["Married","Separated","Single"],dtype=int)
df_Marital.drop("Separated",axis = 1 , inplace = True)
credit_marital= pd.concat([credit_marital,df_Marital],axis=1).drop("Marital_status",axis = 1)
credit_marital = credit_marital.dropna()
credit_marital

# Dwelling ---> [ Categorical --> Numerical ]
LE5 = LabelEncoder()
credit_dwell = credit_marital.copy()
ary5 = LE5.fit_transform(credit_dwell[["Dwelling"]])
df_dwell = pd.DataFrame(ary5,columns=["Housing_Type"])
credit_dwell = pd.concat([credit_dwell,df_dwell],axis = 1)
credit_dwell.drop("Dwelling",axis=1,inplace=True)

print(credit_dwell.shape)
credit_dwell = credit_dwell.dropna()
print(credit_dwell.shape)
credit_dwell
# Out:
# ...
# ====> ['Commercial associate' 'Pensioner' 'State servant' 'Working'] <====
#                   0                 1          2              3
# ...
# ID                    50
# Gender                50
# Has_a_car             50
# Has_a_property        50
# Children_count        50
# Income                50
# Education_level       50
# Marital_status        50
# Dwelling              50
# Has_a_mobile_phone    50
# Has_a_work_phone      50
# Has_a_phone           50
# Has_an_email          50
# Job_Title             50
# Family_Members        50
# label                 50
# Age                   50
# Employed_Years        50
# Income_Type           50
# dtype: int64
# (1495, 19)
# ...
# ID                    49
# Gender                49
# Has_a_car             49
# Has_a_property        49
# Children_count        49
# Income                49
# Education_level       49
# Marital_status        49
# Dwelling              49
# Has_a_mobile_phone    49
# Has_a_work_phone      49
# ...

# %% [markdown]
# ## Insights:
# * Now all the data has been converted to Numerical Values
# * We will convert the Employed years 1000 to NaN and will be doing the Imputation

# %% [markdown]
# ## 1.9.2 Imputation Methods [Mean, Median, Mode, KNN, MICE]

# %%
credit_df  =  credit_dwell.copy()
credit_df.Employed_Years.replace(1000,np.NaN,inplace=True)

# %%
#Mean Imputation
from sklearn.impute import SimpleImputer
credit_mean = credit_df.copy()
mean_imputer = SimpleImputer(strategy="mean")
credit_mean.iloc[:,:] = mean_imputer.fit_transform(credit_mean)

#Median Imputation
from sklearn.impute import SimpleImputer
credit_median = credit_df.copy()
median_imputer = SimpleImputer(strategy="median")
credit_median.iloc[:,:] = median_imputer.fit_transform(credit_median)
credit_median

#Mode Imputation
from sklearn.impute import SimpleImputer
credit_mode = credit_df.copy()
mode_imputer = SimpleImputer(strategy="most_frequent")
credit_mode.iloc[:,:] = mode_imputer.fit_transform(credit_mode)
credit_mode

#KNN imputation
from fancyimpute import KNN
knn_imputer = KNN()
credit_knn = credit_df.copy()
credit_knn.iloc[:,:] = knn_imputer.fit_transform(credit_knn)
credit_knn

from fancyimpute import IterativeImputer
MICE_imputer = IterativeImputer()
credit_MICE = credit_df.copy(deep=True)
credit_MICE.iloc[:, :] = MICE_imputer.fit_transform(credit_MICE)

fig, axes = plt.subplots(2,3, figsize=(15,10))
axes[1][2].set_visible(False)

axes[1][0].set_position([0.24,0.125,0.228,0.343])
axes[1][1].set_position([0.55,0.125,0.228,0.343])
nullity = credit_df['Employed_Years'].isnull() + credit_df['Age'].isnull()
imputations = {'Mean Imputation': credit_mean,
               'Median Imputation': credit_median,
               'Most Frequent Imputation': credit_mode,
               'KNN Imputation': credit_knn,
              'MICE Imputation': credit_MICE}

for ax, df_key in zip(axes.flatten(), imputations):
    imputations[df_key].plot(x='Employed_Years',y="Employed_Years",kind='scatter',
                             alpha=0.5, c=nullity, cmap='rainbow', ax=ax,
                             colorbar=False, title=df_key)
# Out:
# Imputing row 1/1261 with 1 missing, elapsed time: 0.227
# Imputing row 101/1261 with 0 missing, elapsed time: 0.228
# Imputing row 201/1261 with 0 missing, elapsed time: 0.229
# Imputing row 301/1261 with 0 missing, elapsed time: 0.230
# Imputing row 401/1261 with 0 missing, elapsed time: 0.231
# Imputing row 501/1261 with 0 missing, elapsed time: 0.232
# Imputing row 601/1261 with 0 missing, elapsed time: 0.233
# Imputing row 701/1261 with 0 missing, elapsed time: 0.233
# Imputing row 801/1261 with 0 missing, elapsed time: 0.234
# Imputing row 901/1261 with 0 missing, elapsed time: 0.235
# Imputing row 1001/1261 with 0 missing, elapsed time: 0.235
# Imputing row 1101/1261 with 0 missing, elapsed time: 0.236
# Imputing row 1201/1261 with 0 missing, elapsed time: 0.237

# %%
# Taking our imputed Employed_Length Column to the Main DataFrame
credit_df = credit_knn.copy()
credit_employ = credit_df[["ID","Employed_Years"]]
credit_sql = credit_employ.merge(credit_SQL,how="inner" , on = ["ID"])
credit_sql.drop("Employed_Years_y",axis=1,inplace=True)
credit_sql
# Out:
#              ID  Employed_Years_x Gender Has_a_car Has_a_property  \
# 0    5008827.00              6.27      M         Y              Y
# 1    5008865.00              8.00      F         Y              Y
# 2    5008889.00              3.00      F         N              Y
# 3    5009000.00              2.00      M         Y              Y
# 4    5009023.00              8.00      F         N              Y
# ...         ...               ...    ...       ...            ...
# 1256 5126034.00              2.00      F         Y              Y
# 1257 5126101.00             33.96      F         N              Y
# 1258 5126108.00             35.00      F         N              Y
# 1259 5126121.00              0.00      F         Y              N
# 1260 5126124.00              0.00      F         Y              N
#
#       Children_count    Income           Type_Income  \
# 0                  0 180000.00             Pensioner
# 1                  2 135000.00               Working
# ...

# %%
# rename the features to a more readable feature names
credit_sql= credit_sql.rename(columns={
    'Employed_Years_x'     :'Employment_Years',
    'label'                :'Outcome'
        })

# %%
CREDIT_SQL = credit_sql.copy()
print(CREDIT_SQL.columns)
# Rearranging the dataset
CREDIT_SQL = CREDIT_SQL[['ID', 'Gender','Has_a_car','Has_a_property',
                         'Children_count', 'Income', 'Type_Income',
                         'Education_level','Marital_status','Dwelling',
                         'Age','Employment_Years','Has_a_mobile_phone',
                         'Has_a_work_phone','Has_a_phone','Has_an_email',
                         'Job_Title','Family_Members','Outcome']]
# Out:
# Index(['ID', 'Employment_Years', 'Gender', 'Has_a_car', 'Has_a_property',
#        'Children_count', 'Income', 'Type_Income', 'Education_level',
#        'Marital_status', 'Dwelling', 'Has_a_mobile_phone', 'Has_a_work_phone',
#        'Has_a_phone', 'Has_an_email', 'Job_Title', 'Family_Members', 'Outcome',
#        'Age'],
#       dtype='object')

# %% [markdown]
# ## Insights:
# * Hence the data is ready for the SQL part of the Project.

# %% [markdown]
# # **ML Part of the Project**

# %% [markdown]
# ## 2.1 Exploratory Data Analysis (EDA)

# %%
credit_ml = credit_ML.copy()
credit_ml
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0      180000.00
# 1     5009744      F         Y             N         0      315000.00
# 2     5009746      F         Y             N         0      315000.00
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0      315000.00
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0      225000.00
# 1545  5115992      M         Y             Y         2      180000.00
# 1546  5118219      M         Y             N         0      270000.00
# 1547  5053790      F         Y             Y         0      225000.00
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %% [markdown]
# #### Insights:
# * For the Data Visualization Part
# * We will remove all the NaN Values and convert Birthday_Count and Employed_Days which are in days to years

# %% [markdown]
# ## 2.2  Column Renaming

# %%
#Renaming the Features names
credit_ml= credit_ml.rename(columns={
    "Ind_ID"            :"ID",
    'GENDER'            :'Gender',
    'Car_Owner'         :'Has_A_Car',
    'Propert_Owner'     :'Has_A_Property',
    'Birthday_count'    :'Birthday_Count',
    'CHILDREN'          :'Children_Count',
    'Annual_income'     :'Income',
    'NAME_INCOME_TYPE'  :'Employment_Status',
    'EDUCATION'         :'Education_Level',
    'Housing_type'      :'Dwelling',
    'Employed_days'     :'Employment_Length',
    'Mobile_phone'      :'Has_A_Mobile_Phone',
    'Work_Phone'        :"Has_A_Work_Phone",
    'Phone'             :'Has_A_Phone',
    'EMAIL_ID'          :'Has_An_Email',
    'Type_Occupation'   :'Job_Title',
    'Marital_status'    :'Marital_Status',
    'label'             :'Outcome' 
    })

# %% [markdown]
# ## 2.3 Dropping Null Values

# %%
# Finding the Null Values in the data
credit_ml.isna().sum()
# Out:
# ID                      0
# Gender                  7
# Has_A_Car               0
# Has_A_Property          0
# Children_Count          0
# Income                 23
# Type_Income             0
# Education_Level         0
# Marital_Status          0
# Dwelling                0
# Birthday_Count         22
# Employment_Length       0
# Has_A_Mobile_Phone      0
# Has_A_Work_Phone        0
# Has_A_Phone             0
# Has_An_Email            0
# Job_Title             488
# Family_Members          0
# Outcome                 0
# dtype: int64

# %% [markdown]
# ### Insights:
# * For Gender , Income , Birthday_count we will remove that using the dropna() Function
# * In Job_Title We will convert NaN values to "Not_Employed"

# %%
print(credit_ml.dropna(subset=["Gender","Income","Birthday_Count"],inplace=True))
print((credit_ml.isnull().sum() / 1496 )*100) #percentage of Null values in each Columns
print("======================================")
# Out:
# None
# ID                    0.00
# Gender                0.00
# Has_A_Car             0.00
# Has_A_Property        0.00
# Children_Count        0.00
# Income                0.00
# Type_Income           0.00
# Education_Level       0.00
# Marital_Status        0.00
# Dwelling              0.00
# Birthday_Count        0.00
# Employment_Length     0.00
# Has_A_Mobile_Phone    0.00
# Has_A_Work_Phone      0.00
# Has_A_Phone           0.00
# Has_An_Email          0.00
# Job_Title            31.48
# Family_Members        0.00
# Outcome               0.00
# dtype: float64
# ...

# %% [markdown]
# Insights:
# * We will drop the Job_Title Column as it contain the 31% percent of Null Values which can effect our Ml Model.

# %%
credit_ml.drop("Job_Title",axis=1,inplace=True)

# %% [markdown]
# ## 2.4 Converting Negative [Days] to Years

# %%
# Birthday_Count ---> Age
age = np.abs((credit_ml.Birthday_Count)/365)
df_age = pd.DataFrame(age,dtype=int)
df_age = df_age.rename(columns={"Birthday_Count":"Age"})
credit_ml = pd.concat([credit_ml,df_age],axis=1).drop("Birthday_Count",axis=1)

# Employed_Length ---> Employed_Age
days = np.abs((credit_ml.Employment_Length)/365)
df_days = pd.DataFrame(days,dtype=int)
df_days = df_days.rename(columns={"Employment_Length":"Employed_Years"})
credit_ml = pd.concat([credit_ml,df_days],axis=1).drop("Employment_Length",axis=1)
credit_ml
# Out:
#            ID Gender Has_A_Car Has_A_Property  Children_Count    Income  \
# 0     5008827      M         Y              Y               0 180000.00
# 1     5009744      F         Y              N               0 315000.00
# 4     5009752      F         Y              N               0 315000.00
# 6     5009754      F         Y              N               0 315000.00
# 7     5009894      F         N              N               0 180000.00
# ...       ...    ...       ...            ...             ...       ...
# 1542  5118268      M         Y              N               1 360000.00
# 1544  5023655      F         N              N               0 225000.00
# 1545  5115992      M         Y              Y               2 180000.00
# 1546  5118219      M         Y              N               0 270000.00
# 1547  5053790      F         Y              Y               0 225000.00
#
#                Type_Income                Education_Level  \
# ...

# %% [markdown]
# ## 2.5 Development of Visualization and Value Count Functions

# %%
#function that will return the value count and frequency of each observation with in the feature
def value_cnt_norm_cal(df,feature):
    ftr_value_cnt = df[feature].value_counts()
    ftr_value_cnt_norm = df[feature].value_counts(normalize=True) * 100
    ftr_value_cnt_concat = pd.concat([ftr_value_cnt , ftr_value_cnt_norm],axis=1)
    ftr_value_cnt_concat.columns = ["Count","Frequency(%)"]
    return ftr_value_cnt_concat

# %%
def gen_info_feat(df,feature):
    if feature == "Age" or feature == "Employed_Years":
        print('Description:\n{}'.format(df[feature].describe()))
        print('*'*50)
        print('Object type:\n{}'.format(df[feature].dtype))

    else:    
        print('Description:\n{}'.format(df[feature].describe()))
        print('*'*50)
        print('Object type:\n{}'.format(df[feature].dtype))
        print('*'*50)
        value_cnt = value_cnt_norm_cal(df,feature)
        print('Value count:\n{}'.format(value_cnt))

# %%
# function to create a Pie chart plot
def create_piechart(df, column):
    if column == "Dwelling" or "Education_Level":
        fig, ax = plt.subplots(figsize=(18,8))
        value_counts = df[column].value_counts()
        labels = value_counts.index
        values = value_counts.values
        num_slices = len(labels)
        plt.pie(values, autopct='%1.f%%',labeldistance=1.1,startangle=90)
        sns.set_style("white")
        plt.title(column + ' Distribution')
        plt.legend(loc='best',labels=value_counts.index)
        plt.show()
    else:
        fig, ax = plt.subplots(figsize=(18,8))
        value_counts = df[column].value_counts()
        labels = value_counts.index
        values = value_counts.values
        num_slices = len(labels)
        plt.pie(values, labels=labels, autopct='%1.f%%',labeldistance=1.1,startangle=90)
        sns.set_style("white")
        plt.title(column + ' Distribution')
        plt.legend(loc='best')
        plt.show()

# %%
def create_bar_plot(df,feature):
        if feature == 'Marital_Status' or 'Dwelling' or 'Employment_Status' or 'Education_Level':
            fig, ax = plt.subplots(figsize=(6,10))
            sns.barplot(x=value_cnt_norm_cal(df,feature).index,y=value_cnt_norm_cal(df,feature).values[:,0])
            ax.set_xticklabels(labels=value_cnt_norm_cal(df,feature).index,rotation=45,ha='right')
            plt.xlabel('{}'.format(feature))
            plt.ylabel('Count')
            plt.title('{} count'.format(feature))
            return plt.show()

# %%
# function to create a bar chart plot
def create_barplot(df,feature):
            fig, ax = plt.subplots(figsize=(6,10))
            sns.barplot(x=value_cnt_norm_cal(df,feature).index,y=value_cnt_norm_cal(df,feature).values[:,0])
            plt.xlabel('{}'.format(feature))
            plt.ylabel('Count')
            plt.title('{} count'.format(feature))
            return plt.show()

# %%
# High risk vs low risk applicants compared on a box plot
def outcome_box_plot(df,feature):
        if feature == 'Income':
            print(np.abs(df.groupby('Outcome')[feature].mean()))
            fig, ax = plt.subplots(figsize=(5,8))
            sns.boxplot(y=np.abs(df[feature]),x=df['Outcome'])
            plt.xticks(ticks=[0,1],labels=['no','yes'])
            sns.set_style("whitegrid")    
            # suppress scientific notation
            ax.get_yaxis().set_major_formatter(
            matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
            plt.title('Outcome Grouped By {}'.format(feature))
            return plt.show()
        else :
            print(np.abs(df.groupby('Outcome')[feature].mean()))
            sns.set_style("whitegrid")    
            fig, ax = plt.subplots(figsize=(5,8))
            sns.boxplot(y=np.abs(df[feature]),x=df['Outcome'])
            plt.xticks(ticks=[0,1],labels=['Yes','No'])
            plt.title('Outcome Grouped By {}'.format(feature))
            return plt.show()

# %%
def create_box_plot(df,feature):
    fig, ax = plt.subplots(figsize=(2,8))
    sns.set_style("whitegrid")    
    sns.boxplot(y=df[feature])
    plt.title('{} distribution(Boxplot)'.format(feature))
    return plt.show()

# %%
def create_hist_plot(df,feature,the_bins=50):
    fig, ax = plt.subplots(figsize=(18,10))
    sns.histplot(df[feature],bins=the_bins,kde=True)
    sns.set_style("whitegrid")
    plt.title('{} distribution'.format(feature))
    return plt.show()

# %%
# High risk vs low risk applicants compared on a bar plot
def outcome_bar_plot(df,feature):
    Outcome_grp = df.groupby(feature)['Outcome'].sum()
    Outcome_grp_srt = Outcome_grp.sort_values(ascending=False)
    print(dict(Outcome_grp_srt))
    fig, ax = plt.subplots(figsize=(6,10))
    sns.barplot(x=Outcome_grp_srt.index,y=Outcome_grp_srt.values)
    ax.set_xticklabels(labels=Outcome_grp_srt.index,rotation=45, ha='right')
    plt.ylabel('Count')
    plt.title('Outcome count grouped by {}'.format(feature))
    return plt.show()

# %% [markdown]
# # 3. Data Visualization

# %% [markdown]
# #### 3.1 Gender [Univariate ]

# %%
gen_info_feat(credit_ml,"Gender")
# Out:
# Description:
# count     1496
# unique       2
# top          F
# freq       947
# Name: Gender, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#    Count  Frequency(%)
# F    947         63.30
# M    549         36.70

# %%
create_barplot(credit_ml,"Gender")

# %%
create_piechart(credit_ml,"Gender")

# %% [markdown]
# #### Insights:
# * We have more female applicants than male (63% vs 37%)

# %% [markdown]
# #### 3.2 Age [Univariate ,Bi-Variate]

# %%
gen_info_feat(credit_ml,"Age")
# Out:
# Description:
# count   1496.00
# mean      43.43
# std       11.58
# min       21.00
# 25%       34.00
# 50%       42.50
# 75%       53.00
# max       68.00
# Name: Age, dtype: float64
# **************************************************
# Object type:
# int32

# %%
create_box_plot(credit_ml,"Age")

# %%
create_hist_plot(credit_ml,"Age")

# %% [markdown]
# #### Bivariate Analysis with Our Target["Outcome"] Variable

# %%
outcome_box_plot(credit_ml,"Age")
# Out:
# Outcome
# 0   43.26
# 1   44.83
# Name: Age, dtype: float64

# %% [markdown]
# #### Insights:
# * The Youngest applicant is 21 Years old while the oldest is 68 with the Average[Mean] of 43.4 and Median of 42.5 (Outlier Insensitive)
# * Age feature is not Normally Distributed , It is slighly Positively Skewed
# * There is No difference between the Average Age of Approved and Disapproved of the Credit Card.

# %% [markdown]
# #### 3.3 Marital_Status [Univariate ,Bi-Variate]

# %%
gen_info_feat(credit_ml,'Marital_Status')
# Out:
# Description:
# count        1496
# unique          5
# top       Married
# freq         1011
# Name: Marital_Status, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#                       Count  Frequency(%)
# Married                1011         67.58
# Single / not married    218         14.57
# Civil marriage          101          6.75
# Separated                91          6.08
# Widow                    75          5.01

# %%
create_piechart(credit_ml,'Marital_Status')

# %%
create_barplot(credit_ml,"Marital_Status")

# %%
outcome_bar_plot(credit_ml,"Marital_Status")
# Out:
# {'Married': 104, 'Single / not married': 32, 'Separated': 12, 'Widow': 8, 'Civil marriage': 4}

# %% [markdown]
# #### Insights:
# * Most_Applicants are Married.
# * Even Though we have high number of applicants who are separted than those who are widow , it seems like widow applicants are high risk then separted,

# %% [markdown]
# #### 3.4 Family_Members [Univariate ]

# %%
gen_info_feat(credit_ml,"Family_Members")
# Out:
# Description:
# count   1496.00
# mean       2.17
# std        0.95
# min        1.00
# 25%        2.00
# 50%        2.00
# 75%        3.00
# max       15.00
# Name: Family_Members, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#     Count  Frequency(%)
# 2     773         51.67
# 1     322         21.52
# 3     261         17.45
# 4     123          8.22
# 5      15          1.00
# 6       1          0.07
# 15      1          0.07

# %%
create_box_plot(credit_ml,"Family_Members")

# %%
create_barplot(credit_ml,"Family_Members")

# %% [markdown]
# #### Insights:
# * Most of the two in their household , this is also confirmed with the fact that most don't have a child (more on this in a bit)
# * We also have 3 Outliers and 1 is Extreme Outlier with 15 in their Household.

# %% [markdown]
# #### 3.5 Children_Count [Univariate]

# %%
gen_info_feat(credit_ml,"Children_Count")
# Out:
# Description:
# count   1496.00
# mean       0.42
# std        0.78
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        1.00
# max       14.00
# Name: Children_Count, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#     Count  Frequency(%)
# 0    1051         70.25
# 1     298         19.92
# 2     129          8.62
# 3      16          1.07
# 4       1          0.07
# 14      1          0.07

# %%
create_box_plot(credit_ml,'Children_Count')

# %%
create_barplot(credit_ml,'Children_Count')

# %% [markdown]
# #### Insights:
# * As Discussed above Most applicants dont have a child.
# * Also We have 3 Outliers , Probably with the same number of Family Member Count.

# %% [markdown]
# #### 3.6 Dwelling [Uni-Variate]

# %%
gen_info_feat(credit_ml,'Dwelling')
# Out:
# Description:
# count                  1496
# unique                    6
# top       House / apartment
# freq                   1331
# Name: Dwelling, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#                      Count  Frequency(%)
# House / apartment     1331         88.97
# With parents            79          5.28
# Municipal apartment     51          3.41
# Rented apartment        21          1.40
# Office apartment         9          0.60
# Co-op apartment          5          0.33

# %%
create_piechart(credit_ml,'Dwelling')

# %%
create_bar_plot(credit_ml,'Dwelling')

# %% [markdown]
# #### 3.7 Income [Uni-Variate ,Bi-Variate]

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)
gen_info_feat(credit_ml,'Income')
# Out:
# Description:
# count      1496.00
# mean     190775.05
# std      113138.37
# min       33750.00
# 25%      121050.00
# 50%      166050.00
# 75%      225000.00
# max     1575000.00
# Name: Income, dtype: float64
# **************************************************
# Object type:
# float64
# **************************************************
# Value count:
#            Count  Frequency(%)
# 135000.00    166         11.10
# 112500.00    143          9.56
# 180000.00    136          9.09
# 157500.00    121          8.09
# 225000.00    117          7.82
# ...          ...           ...
# 72900.00       1          0.07
# 301500.00      1          0.07
# 95850.00       1          0.07
# 115200.00      1          0.07
# 114750.00      1          0.07
#
# [115 rows x 2 columns]

# %%
create_box_plot(credit_ml,'Income')

# %%
create_hist_plot(credit_ml,"Income")

# %% [markdown]
# #### Bivariate Analysis with Target Variable

# %%
outcome_box_plot(credit_ml,"Income")
# Out:
# Outcome
# 0   190300.50
# 1   194737.50
# Name: Income, dtype: float64

# %% [markdown]
# #### Insights:
# -	The average income is 190775.05 but this amount accounts for outliers. If we ignore the outlier most people make 166050.00
# -	We have 3 applicants who makes more than 1000000
# -	This feature is positively skewed
# -   Approved  and Disapproved applicants have roughly similar income

# %% [markdown]
# ### 3.8 Type_Income [Uni-Variate ]

# %%
gen_info_feat(credit_ml,"Type_Income")
# Out:
# Description:
# count        1496
# unique          4
# top       Working
# freq          769
# Name: Type_Income, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#                       Count  Frequency(%)
# Working                 769         51.40
# Commercial associate    353         23.60
# Pensioner               259         17.31
# State servant           115          7.69

# %%
create_bar_plot(credit_ml,"Type_Income")

# %%
create_piechart(credit_ml,"Type_Income")

# %% [markdown]
# #### Insights:
# * Most Applicants are Employed

# %% [markdown]
# #### 3.9 Education_Level [Univariate]

# %%
gen_info_feat(credit_ml,"Education_Level")
# Out:
# Description:
# count                              1496
# unique                                5
# top       Secondary / secondary special
# freq                                998
# Name: Education_Level, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#                                Count  Frequency(%)
# Secondary / secondary special    998         66.71
# Higher education                 409         27.34
# Incomplete higher                 66          4.41
# Lower secondary                   21          1.40
# Academic degree                    2          0.13

# %%
create_piechart(credit_ml,"Education_Level")

# %%
create_bar_plot(credit_ml,"Education_Level")

# %% [markdown]
# #### Insights:
# * The Majority of Applicants Have completed their secondary degree , 1/4 of their higher Education.

# %% [markdown]
# ### 3.10 Employed_Years [Uni-variate,Bi-variate]

# %%
gen_info_feat(credit_ml,'Employed_Years')
# Out:
# Description:
# count   1496.00
# mean     174.16
# std      371.87
# min        0.00
# 25%        3.00
# 50%        6.00
# 75%       16.00
# max     1000.00
# Name: Employed_Years, dtype: float64
# **************************************************
# Object type:
# int32

# %%
create_box_plot(credit_ml,"Employed_Years")

# %%
create_hist_plot(credit_ml,"Employed_Years")

# %% [markdown]
# #### Bivariate Analysis With Target Variable

# %%
# distribution of employment length for high vs low risk applicants
# Here 0 means No and 1 means Yes
outcome_box_plot(credit_ml,"Employed_Years")
# Out:
# Outcome
# 0   171.34
# 1   197.75
# Name: Employed_Years, dtype: float64

# %% [markdown]
# #### 3.11 Has_A_Car [Uni-Variate]

# %%
gen_info_feat(credit_ml,"Has_A_Car")
# Out:
# Description:
# count     1496
# unique       2
# top          N
# freq       898
# Name: Has_A_Car, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#    Count  Frequency(%)
# N    898         60.03
# Y    598         39.97

# %%
create_barplot(credit_ml,"Has_A_Car")

# %%
create_piechart(credit_ml,"Has_A_Car")

# %% [markdown]
# #### Insights:
# *    Most applicants don't Owns a Car.

# %% [markdown]
# ### 3.12 Has_A_Property [Uni-Variate]

# %%
gen_info_feat(credit_ml,"Has_A_Property")
# Out:
# Description:
# count     1496
# unique       2
# top          Y
# freq       977
# Name: Has_A_Property, dtype: object
# **************************************************
# Object type:
# object
# **************************************************
# Value count:
#    Count  Frequency(%)
# Y    977         65.31
# N    519         34.69

# %%
create_barplot(credit_ml,"Has_A_Property")

# %%
create_piechart(credit_ml,"Has_A_Property")

# %% [markdown]
# #### Insights:
# * Most Applicants Owns a Car.

# %% [markdown]
# ### 3.13 Has_A_Work_Phone

# %%
gen_info_feat(credit_ml,"Has_A_Work_Phone")
# Out:
# Description:
# count   1496.00
# mean       0.21
# std        0.40
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max        1.00
# Name: Has_A_Work_Phone, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#    Count  Frequency(%)
# 0   1188         79.41
# 1    308         20.59

# %%
create_barplot(credit_ml,"Has_A_Work_Phone")

# %%
create_piechart(credit_ml,"Has_A_Work_Phone")

# %% [markdown]
# #### Insights:
# * More than 3/4 of the applicant dont have the work phone.

# %% [markdown]
# ### 2.3.14 Has_A_Mobile_Phone

# %%
gen_info_feat(credit_ml,"Has_A_Mobile_Phone")
# Out:
# Description:
# count   1496.00
# mean       1.00
# std        0.00
# min        1.00
# 25%        1.00
# 50%        1.00
# 75%        1.00
# max        1.00
# Name: Has_A_Mobile_Phone, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#    Count  Frequency(%)
# 1   1496        100.00

# %%
create_piechart(credit_ml,"Has_A_Mobile_Phone")

# %% [markdown]
# #### Insights:
# * All the applicants without exception has the mobile phone.

# %% [markdown]
# ### 3.15 Has_A_Phone[Uni-Variate]

# %%
gen_info_feat(credit_ml,"Has_A_Phone")
# Out:
# Description:
# count   1496.00
# mean       0.30
# std        0.46
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        1.00
# max        1.00
# Name: Has_A_Phone, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#    Count  Frequency(%)
# 0   1040         69.52
# 1    456         30.48

# %%
create_barplot(credit_ml,"Has_A_Phone")

# %%
create_piechart(credit_ml,"Has_A_Phone")

# %% [markdown]
# #### Insights:
# * Most Applicants don't have a phone (Probably the Home Phone)

# %% [markdown]
# ### 2.16 Has_An_Email [Univariate]

# %%
gen_info_feat(credit_ml,"Has_An_Email")
# Out:
# Description:
# count   1496.00
# mean       0.09
# std        0.29
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max        1.00
# Name: Has_An_Email, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#    Count  Frequency(%)
# 0   1355         90.57
# 1    141          9.43

# %%
create_barplot(credit_ml,'Has_An_Email')

# %%
create_piechart(credit_ml,'Has_An_Email')

# %% [markdown]
# #### Insights:
# * More than 90% of the Applicants don't have an Email.

# %% [markdown]
# #### 2.1.17 Outcome ( Target Variable )

# %%
gen_info_feat(credit_ml,"Outcome")
# Out:
# Description:
# count   1496.00
# mean       0.11
# std        0.31
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max        1.00
# Name: Outcome, dtype: float64
# **************************************************
# Object type:
# int64
# **************************************************
# Value count:
#    Count  Frequency(%)
# 0   1336         89.30
# 1    160         10.70

# %%
create_barplot(credit_ml,'Outcome')

# %%
create_piechart(credit_ml,'Outcome')

# %% [markdown]
# #### Insights:
# * A Major Majority of the applicants have been Approved for Credit Card.

# %% [markdown]
# ### 3.18 Numerical V/S Numerical Features (Co-Relation & Scatter Plots)

# %%
sns.pairplot(credit_ml,hue="Outcome",diag_kind="hist",palette="bright");

# %% [markdown]
# #### Insights:
#
# - We can see a positive linear correlation between the family member and the children count. This makes sense, the more the children someone have, the larger the family member count. This is a multicollinearity problem. Meaning that the features are highly correlated. We will need to drop one of them.
# - Another interesting trend is the Employment length and age. This also makes sense, the longer the employee has been working, the older they are.

# %% [markdown]
# #### 3.19 Family member count vs children count (numerical vs numerical feature comparison)

# %%
sns.regplot(x='Children_Count',y='Family_Members',data=credit_ml,line_kws={'color': 'red'})
plt.show()

# %% [markdown]
# #### Insights:
# The More the Children  a person has , The larger the Family Members count

# %% [markdown]
# ### 3.20 Co-Relation Analysis

# %%
# correlation analysis with heatmap, after dropping the has a mobile phone with the target feature as int
credit_corr_no_mobile = credit_ml.drop('Has_A_Mobile_Phone', axis=1).corr()
# Get the lower triangle of the correlation matrix
# Generate a mask for the upper triangle
mask = np.zeros_like(credit_corr_no_mobile, dtype='bool')
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(18,10))
# seaborn heatmap
sns.heatmap(credit_corr_no_mobile, annot=True, cmap='flare',mask=mask, linewidths=.5)
# plot the heatmap
plt.show()

# %% [markdown]
# #### Insights:
# - There is no feature that is correlated with the target feature
# - Family member count is highly correlated with children count as previously discussed
# - Age has some positive correlation with the family member count and children count. The older a person is, the most likely he/she will have a larger family.
# - Another positive correlation is having a phone and having a work phone.
# - The final positive correlation is between the age and work phone. The younger someone is the less likely he/she will have a work phone.
# - We also have a negative correlation between the employment length and the age as previously seen.

# %% [markdown]
# ## 2.3.3 Categorical vs categorical features (Chi-square test)

# %% [markdown]
# Null hypothesis: The feature's categories have no effect on the target variable
#
# Alternative hypothesis (one or more) of the feature categories has a signifcant effect on the target valriable

# %%
def chi_func(feature):
    # selection row with high risk
    high_risk_ft = credit_ml[credit_ml['Outcome'] == 1][feature]
    high_risk_ft_ct = pd.crosstab(index=high_risk_ft, columns=['Count']).rename_axis(None, axis=1)
    # drop the index feature name
    high_risk_ft_ct.index.name = None
    # observe values
    obs = high_risk_ft_ct
    print('Observed values:\n')
    print(obs)
    print('\n')
    # expected values
    print(obs.index)
    exp = pd.DataFrame([obs['Count'].sum()/len(obs)] * len(obs.index),columns=['Count'], index=obs.index)
    print('Expected values:\n')
    print(exp)
    print('\n')
    # chi-square test
    chi_squared_stat = (((obs-exp)**2)/exp).sum()
    print('Chi-square:\n')
    print(chi_squared_stat[0])
    print('\n')
    #critical value
    crit = stats.chi2.ppf(q = 0.95, df = len(obs) - 1)
    print('Critical value:\n')
    print(crit)
    print('\n')
    # p-value
    p_value = 1 - stats.chi2.cdf(x = chi_squared_stat, df = len(obs) - 1)
    print('P-value:\n')
    print(p_value)
    print('\n')
    if chi_squared_stat[0] >= crit:
        print('Reject the null hypothesis')
    elif chi_squared_stat[0] <= crit:
        print('Fail to reject the null hypothesis')

# %%
credit_ml.columns
# Out:
# Index(['ID', 'Gender', 'Has_A_Car', 'Has_A_Property', 'Children_Count',
#        'Income', 'Type_Income', 'Education_Level', 'Marital_Status',
#        'Dwelling', 'Has_A_Mobile_Phone', 'Has_A_Work_Phone', 'Has_A_Phone',
#        'Has_An_Email', 'Family_Members', 'Outcome', 'Age', 'Employed_Years'],
#       dtype='object')

# %%
cat_ft = ['Gender', 'Has_A_Car', 'Has_A_Property', 'Employed_Years', 'Education_Level', 'Marital_Status', 'Dwelling']
for ft in cat_ft:
    print('\n\n**** {} ****\n'.format(ft))
    chi_func(ft)
# Out:
# **** Gender ****
#
# Observed values:
#
#    Count
# F     89
# M     71
#
#
# Index(['F', 'M'], dtype='object')
# Expected values:
#
#    Count
# F  80.00
# M  80.00
#
#
# Chi-square:
#
# 2.025
#
#
# Critical value:
#
# 3.841458820694124
#
#
# P-value:
#
# [0.15472892]
#
#
# Fail to reject the null hypothesis
#
#
# **** Has_A_Car ****
#
# Observed values:
#
#    Count
# N    101
# Y     59
#
#
# Index(['N', 'Y'], dtype='object')
# Expected values:
#
#    Count
# N  80.00
# Y  80.00
#
#
# Chi-square:
#
# 11.025
#
#
# Critical value:
#
# 3.841458820694124
#
#
# P-value:
#
# [0.00089891]
#
#
# Reject the null hypothesis
#
#
# **** Has_A_Property ****
#
# Observed values:
#
#    Count
# N     58
# Y    102
#
#
# Index(['N', 'Y'], dtype='object')
# Expected values:
#
#    Count
# N  80.00
# Y  80.00
#
#
# Chi-square:
#
# 12.1
#
#
# Critical value:
#
# 3.841458820694124
#
#
# P-value:
#
# [0.00050422]
#
#
# Reject the null hypothesis
#
#
# **** Employed_Years ****
#
# Observed values:
#
# ...

# %% [markdown]
# ## 4.0 Preparing the Data for the ML Part

# %% [markdown]
# ### Transformation To be done On Each Feature:

# %% [markdown]
#  #### Data Cleaning

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# #### 4.1 **DROP Features based on Visualization**
#
# Why are we droping these features?
# - ID: ID is not useful for prediction, it helped us when we were merging the two datasets but after that, there is no need to keep it.
# - Has a mobile phone: Since everyone has a mobile phone, this feature does not inform us about anything.
# - Children count: is highly correlated with Family member count, and to avoid multicollinearity, we drop it.
# - Job title: Has some missing values and the count of each category is not very different to justify the use of mode. So we drop it.

# %%
credit_ml.drop(["ID","Has_A_Mobile_Phone","Children_Count"],axis=1,inplace=True)

# %% [markdown]
# ## 4.2 Data Encoding of Nominal Data [get_dummies]:
# * Gender           - [Nominal Data]
# * Has_A_Car        - [Nominal Data]
# * Has_A_Work_Phone - [Nominal Data]
# * Marital_Status   - [Nominal Data]
# * Dwelling         - [Nominal Data]
# * Type_Income      - [Nominal Data]
#
#
#
# - **As all of these data are Nominal we will use the Pd.get_dummies [Dummy Variable] to convert them into the Numerical Values and will use the drop_first function of the get_dummies function to get rid of the *dummy trap* .**

# %%
ml_enco = credit_ml.copy()

# %%
dummy_fea = pd.get_dummies(ml_enco[["Gender","Has_A_Car","Has_A_Property","Has_A_Work_Phone","Marital_Status","Dwelling","Type_Income"]],drop_first=True)
dummy_fea = dummy_fea.rename(columns={"Has_A_Work_Phone" :"Work_Phone",
                          "Gender_M"         :"Male",
                          "Has_A_Car_Y"      :"Car",
                          "Has_A_Property_Y" :"Property",
                          "Marital_Status_Married" : "Married",
                          "Marital_Status_Separated":"Separated",
                          "Marital_Status_Single / not married":"Single",
                          "Marital_Status_Widow" : "Widow",
                          "Dwelling_House / apartment":"Apartment",
                          'Dwelling_Municipal apartment' :"Municipal_Apartment",
                          "Dwelling_Office apartment":"Office_Apartment",
                          "Dwelling_Rented apartment" :"Rented_Apartment",
                          "Dwelling_With parents" :"Living_With_Parents",
                          "Type_Income_Pensioner"  : "Pensioner",
                          "Type_Income_State servant":"State_Servent",
                          "Type_Income_Working"   : "Working"
                         })
credit_ml= credit_ml.drop(["Gender","Has_A_Car","Has_A_Work_Phone",
                    "Has_A_Property","Marital_Status","Dwelling","Type_Income"],axis=1)

credit_ml = pd.concat([credit_ml,dummy_fea],axis=1)

# %% [markdown]
# ### 4.3 Data Encoding of Inordinal Data [Label Encoder]

# %%
LE = LabelEncoder()
ary = LE1.fit_transform(credit_ml["Education_Level"])
df_Edu = pd.DataFrame(ary1,columns=["EducationLevel"])
credit_ml = pd.concat([credit_ml,df_Edu],axis=1).drop("Education_Level",axis=1).dropna()

# %% [markdown]
# ### 4.4 Data Imputation [Mean,Median,Mode,KNN,MICE]

# %%
# Replacing the 1000 in Employed Years with np.NaN and 
# Will do the Imputations
credit_ml["Employed_Years"] = credit_ml["Employed_Years"].replace(1000,np.NaN)


#Mean Imputation

train_mean = credit_ml.copy()
mean_imputer = SimpleImputer(strategy="mean")
train_mean.iloc[:,:] = mean_imputer.fit_transform(train_mean)

#Median Imputation
train_median = credit_ml.copy()
median_imputer = SimpleImputer(strategy="median")
train_median.iloc[:,:] = median_imputer.fit_transform(train_median)

#Mode Imputation
from sklearn.impute import SimpleImputer
train_mode = credit_ml.copy()
mode_imputer = SimpleImputer(strategy="most_frequent")
train_mode.iloc[:,:] = mode_imputer.fit_transform(train_mode)
train_mode

#KNN imputation
from fancyimpute import KNN
knn_imputer = KNN()
train_knn = credit_ml.copy()
train_knn.iloc[:,:] = knn_imputer.fit_transform(train_knn)
train_knn

from fancyimpute import IterativeImputer
MICE_imputer = IterativeImputer()
train_MICE = credit_ml.copy(deep=True)
train_MICE.iloc[:, :] = MICE_imputer.fit_transform(train_MICE)

# Data Visualization of the Imputations
fig, axes = plt.subplots(2,3, figsize=(15,10))
axes[1][2].set_visible(False)

axes[1][0].set_position([0.24,0.125,0.228,0.343])
axes[1][1].set_position([0.55,0.125,0.228,0.343])
nullity = credit_ml['Employed_Years'].isnull() + credit_ml['Age'].isnull()
imputations = {'Mean Imputation': train_mean,
               'Median Imputation': train_median,
               'Most Frequent Imputation': train_mode,
               'KNN Imputation': train_knn,
              'MICE Imputation': train_MICE}

for ax, df_key in zip(axes.flatten(), imputations):
    imputations[df_key].plot(x='Employed_Years',y="Employed_Years",kind='scatter',
                             alpha=0.5, c=nullity, cmap='rainbow', ax=ax,
                             colorbar=False, title=df_key)
# Out:
# Imputing row 1/1446 with 1 missing, elapsed time: 0.307
# Imputing row 101/1446 with 1 missing, elapsed time: 0.308
# Imputing row 201/1446 with 0 missing, elapsed time: 0.309
# Imputing row 301/1446 with 0 missing, elapsed time: 0.309
# Imputing row 401/1446 with 1 missing, elapsed time: 0.310
# Imputing row 501/1446 with 0 missing, elapsed time: 0.311
# Imputing row 601/1446 with 0 missing, elapsed time: 0.312
# Imputing row 701/1446 with 0 missing, elapsed time: 0.312
# Imputing row 801/1446 with 0 missing, elapsed time: 0.313
# Imputing row 901/1446 with 1 missing, elapsed time: 0.314
# Imputing row 1001/1446 with 0 missing, elapsed time: 0.315
# Imputing row 1101/1446 with 0 missing, elapsed time: 0.315
# Imputing row 1201/1446 with 0 missing, elapsed time: 0.316
# Imputing row 1301/1446 with 1 missing, elapsed time: 0.317
# Imputing row 1401/1446 with 1 missing, elapsed time: 0.318

# %%
credit_ml = train_knn.copy()

# %% [markdown]
# ## 4.5  Removing the Outlier:

# %%
df = pd.DataFrame(data = credit_ml, columns = ["Family_Members","Income","Employed_Years"])
df.boxplot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
outliers_list = ["Family_Members","Income","Employed_Years"]

# %%
def odiqr(df):
        q1 = df.quantile(0.25)
        q3 = df.quantile(0.75)
        iqr = q3 - q1
        low = q1 - (1.5 * iqr)
        high = q3 + (1.5 * iqr)
        m = df.mean()
        df = df.apply(lambda x : m if x < low else (m if x > high else x ) )
        return df

# %%
for i in outliers_list:
    credit_ml[i] = odiqr(df[i])

# %%
df = pd.DataFrame(data = credit_ml, columns = ["Family_Members","Income","Employed_Years"])
df.boxplot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
credit_ml = credit_ml[['Male','Car','Property','Family_Members','Income',
               'Living_With_Parents','Pensioner', 'State_Servent',
               'Working','EducationLevel','Married', 'Separated',
               'Single', 'Widow','Municipal_Apartment',
       'Office_Apartment', 'Rented_Apartment', 'Living_With_Parents',
               'Age','Employed_Years','Has_A_Phone', 'Has_An_Email',
               'Work_Phone',"Outcome"]]

# %% [markdown]
# ## 4.6 Creating the Machine Learning Models:

# %%
kf=KFold(n_splits=10)
rfc=RandomForestClassifier()
dtc=DecisionTreeClassifier(max_depth=10)
lr=LinearRegression()
lreg=LogisticRegression()
svm=SVC(kernel='poly')
abc=AdaBoostClassifier()
bc=BaggingClassifier()
knn=KNeighborsClassifier()

# %%
algo=[rfc,lreg,lr,dtc,svm,abc,bc,knn]

# %%
X=credit_ml.drop("Outcome",axis=1)
y=credit_ml["Outcome"]

# %%
for m in algo:
    res=cross_val_score(m,X,y,cv=kf)
    print("score of ",m,"is",res.mean()*100)
# Out:
# score of  RandomForestClassifier() is 88.41139846743296
# score of  LogisticRegression() is 88.96551724137932
# score of  LinearRegression() is -0.7765934481221759
# score of  DecisionTreeClassifier(max_depth=10) is 84.12356321839081
# score of  SVC(kernel='poly') is 88.96551724137932
# score of  AdaBoostClassifier() is 88.13505747126436
# score of  BaggingClassifier() is 87.44444444444446
# score of  KNeighborsClassifier() is nan

# %% [markdown]
# ## Insights:
# * The Linear Regession Machine Learning Model is Giving us the Best accuracy of 88.5%
# * As well as We get the quite good Accuracy With **Logistic Regression Support Vector Machine (kernel="Poly") , Ada boosting And Bagging Classifier** with accuracy of 88%.
# * Logistic Regression is Giving us the Best accuracy Because its the Classification Problem , And For Classification Probelem Logistic Regresiion is one of the Best Approach

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# * In this project, the objective was to identify the key factors influencing credit card approval by leveraging the capabilities of Data Analysis and Machine Learning.
# * Despite achieving an initial accuracy of 86%, we explored opportunities to enhance performance through grid search. However, the best result obtained from this dataset using both logistic regression and random forest models was 88.9%.
